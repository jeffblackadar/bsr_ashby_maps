# %%
# !pwd
# !cd /content/drive/MyDrive
# !mkdir /content/drive/MyDrive/bsr_ashby_maps
# Out:
# /content

# %%
import os
os.chdir('/content/drive/MyDrive/bsr_ashby_maps/')
# !pwd
#!git init .
# Out:
# /content/drive/MyDrive/bsr_ashby_maps

# %%
import os
os.chdir('/content/drive/MyDrive/bsr_ashby_maps/')
# !pwd
# Out:
# /content/drive/MyDrive/bsr_ashby_maps

# %%
# !git config --global user.email "jeffblackadar@gmail.com"
# !git config --global user.name "jeffblackadar"
#!git config --global user.password ""

# %%
# !git pull
# Out:
# hint: Waiting for your editor to close the file... error: unable to start editor 'editor'
# Not committing merge; use 'git commit' to complete the merge.

# %%
# !git add -A

# %%
# !git pull https://github.com/jeffblackadar/bsr_ashby_maps.git

# %%
# !git commit -m "add ocr"
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
#https://amitness.com/2020/06/google-colaboratory-tips/
import subprocess
input
print('Enter your pat:')
pat = input()
command = "git remote add origin https://"+pat+"@github.com/jeffblackadar/bsr_ashby_maps.git"
subprocess.call(command, shell=True)
command = "git remote set-url origin https://"+pat+"@github.com/jeffblackadar/bsr_ashby_maps.git"
subprocess.call(command, shell=True)
print("delete this output")

# %%
# !git remote -v

# %%
# !git push --set-upstream origin main

# %%
# !git push

# %%
# !git push origin main

# %%
# !git branch -m master main

# %%
# !git pull origin main
# Out:
# error: You have not concluded your merge (MERGE_HEAD exists).
# hint: Please, commit your changes before merging.
# fatal: Exiting because of unfinished merge.

# %%
# !git status

# %%
# !git commit -m "Merge from pull"
# Out:
# [main dc3dc76] Merge from pull

# %%
# !git config http.postBuffer 524288000

# %%
# !git pull origin main --allow-unrelated-histories

# %%
# !git pull origin main

# %%
# !git reset --hard
# Out:
# HEAD is now at a5f6c55 3 commit

# %%
# !git push --help

# %%
# !git --version
# Out:
# git version 2.17.1

# %%
! git add -A

# %%
! git commit -m "Run predictions"
